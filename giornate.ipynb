# %%
import os
import sys
module_path = os.path.abspath(os.path.join('C:/Users/Michela/Desktop/ieva/DATASCIENCE/PROJECTS/PYTHON/Soccer'))
if module_path not in sys.path:
    sys.path.append(module_path)
import pandas as pd
from giornate import Giornate

# %%
url = "https://www.diretta.it/calcio/italia/serie-a-2010-2011/risultati/"
xpath = '//*[@id="fs-results"]'
# xpath = '//*[@class="soccer"]'

gg = Giornate(url=url, xpath=xpath)
gg.process()
gg.df
# Out:
# https://www.diretta.it/calcio/italia/serie-a-2010-2011/risultati/
# //*[@id="fs-results"]
#       Unnamed: 0 ClassificheITALIA: Serie A  Unnamed: 2  Unnamed: 3  \
# 0    Giornata 38                        NaN         NaN         NaN
# 1            NaN               22.05. 20:45    Juventus      Napoli
# 2            NaN               22.05. 20:45       Lecce       Lazio
# 3            NaN               22.05. 20:45        Roma   Sampdoria
# 4            NaN               22.05. 20:45     Udinese       Milan
# 5            NaN               22.05. 18:00     Bologna        Bari
# 6            NaN               22.05. 18:00     Brescia  Fiorentina
# 7            NaN               22.05. 18:00    Cagliari       Parma
# 8            NaN               22.05. 18:00       Genoa      Cesena
# 9            NaN               22.05. 18:00       Inter     Catania
# 10           NaN               22.05. 18:00     Palermo      Chievo
# 11   Giornata 37                        NaN         NaN         NaN
# 12           NaN               15.05. 20:45      Napoli       Inter
# 13           NaN               15.05. 15:00        Bari       Lecce
# 14           NaN               15.05. 15:00     Catania        Roma
# 15           NaN               15.05. 15:00      Cesena     Brescia
# 16           NaN               15.05. 15:00      Chievo     Udinese
# 17           NaN               15.05. 15:00       Parma    Juventus
# 18           NaN               15.05. 15:00   Sampdoria     Palermo
# 19           NaN               15.05. 12:30  Fiorentina     Bologna
# 20           NaN               14.05. 20:45       Milan    Cagliari
# 21           NaN               14.05. 18:00       Lazio       Genoa
# 22   Giornata 36                        NaN         NaN         NaN
# 23           NaN               09.05. 20:45    Juventus      Chievo
# 24           NaN               08.05. 20:45       Genoa   Sampdoria
# 25           NaN               08.05. 15:00     Bologna       Parma
# 26           NaN               08.05. 15:00     Brescia     Catania
# 27           NaN               08.05. 15:00    Cagliari      Cesena
# 28           NaN               08.05. 15:00       Inter  Fiorentina
# 29           NaN               08.05. 15:00       Lecce      Napoli
# ..           ...                        ...         ...         ...
# 91           NaN               20.03. 16:00     Bologna       Genoa
# 92           NaN               20.03. 16:00       Inter       Lecce
# 93           NaN               20.03. 16:00    Juventus     Brescia
# 94           NaN               20.03. 16:00   Sampdoria       Parma
# 95           NaN               20.03. 16:00     Udinese     Catania
# 96           NaN               20.03. 13:30  Fiorentina        Roma
# 97           NaN               19.03. 21:45     Palermo       Milan
# 98           NaN               19.03. 19:00       Lazio      Cesena
# 99   Giornata 29                        NaN         NaN         NaN
# 100          NaN               13.03. 21:45       Parma      Napoli
# 101          NaN               13.03. 16:00    Cagliari     Udinese
# 102          NaN               13.03. 16:00     Catania   Sampdoria
# 103          NaN               13.03. 16:00      Chievo  Fiorentina
# 104          NaN               13.03. 16:00       Genoa     Palermo
# 105          NaN               13.03. 16:00       Lecce     Bologna
# 106          NaN               13.03. 16:00        Roma       Lazio
# 107          NaN               13.03. 13:30       Milan        Bari
# 108          NaN               12.03. 20:45      Cesena    Juventus
# 109          NaN               11.03. 20:45     Brescia       Inter
# 110  Giornata 28                        NaN         NaN         NaN
# 111          NaN               06.03. 20:45       Lazio     Palermo
# 112          NaN               06.03. 15:00     Bologna    Cagliari
# 113          NaN               06.03. 15:00      Chievo       Parma
# 114          NaN               06.03. 15:00  Fiorentina     Catania
# 115          NaN               06.03. 15:00       Inter       Genoa
# 116          NaN               06.03. 15:00      Napoli     Brescia
# 117          NaN               06.03. 15:00     Udinese        Bari
# 118          NaN               06.03. 12:30   Sampdoria      Cesena
# 119          NaN               05.03. 20:45    Juventus       Milan
# 120          NaN               04.03. 20:45       Lecce        Roma
#
#     Unnamed: 4  Unnamed: 5
# 0          NaN         NaN
# 1        2 : 2         NaN
# 2        2 : 4         NaN
# 3        3 : 1         NaN
# 4        0 : 0         NaN
# 5        0 : 4         NaN
# 6        2 : 2         NaN
# 7        1 : 1         NaN
# 8        3 : 2         NaN
# 9        3 : 1         NaN
# 10       1 : 3         NaN
# 11         NaN         NaN
# 12       1 : 1         NaN
# 13       0 : 2         NaN
# 14       2 : 1         NaN
# 15       1 : 0         NaN
# 16       0 : 2         NaN
# 17       1 : 0         NaN
# 18       1 : 2         NaN
# 19       1 : 1         NaN
# 20       4 : 1         NaN
# 21       4 : 2         NaN
# 22         NaN         NaN
# 23       2 : 2         NaN
# 24       2 : 1         NaN
# 25       0 : 0         NaN
# 26       1 : 2         NaN
# 27       0 : 2         NaN
# 28       3 : 1         NaN
# 29       2 : 1         NaN
# ..         ...         ...
# 91       1 : 1         NaN
# 92       1 : 0         NaN
# 93       2 : 1         NaN
# 94       0 : 1         NaN
# 95       2 : 0         NaN
# 96       2 : 2         NaN
# 97       1 : 0         NaN
# 98       1 : 0         NaN
# 99         NaN         NaN
# 100      1 : 3         NaN
# 101      0 : 4         NaN
# 102      1 : 0         NaN
# 103      0 : 1         NaN
# 104      1 : 0         NaN
# 105      0 : 1         NaN
# 106      2 : 0         NaN
# 107      1 : 1         NaN
# 108      2 : 2         NaN
# 109      1 : 1         NaN
# 110        NaN         NaN
# 111      2 : 0         NaN
# 112      2 : 2         NaN
# 113      0 : 0         NaN
# 114      3 : 0         NaN
# 115      5 : 2         NaN
# 116      0 : 0         NaN
# 117      1 : 0         NaN
# 118      2 : 3         NaN
# 119      0 : 1         NaN
# 120      1 : 2         NaN
#
# [121 rows x 6 columns]

# %%
gg.df.drop("Unnamed: 5", axis=1, inplace=True)

# %%
gg.df.head()
# Out:
#     Unnamed: 0 ClassificheITALIA: Serie A Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0  Giornata 38                        NaN        NaN        NaN        NaN
# 1  Giornata 38               22.05. 20:45   Juventus     Napoli      2 : 2
# 2  Giornata 38               22.05. 20:45      Lecce      Lazio      2 : 4
# 3  Giornata 38               22.05. 20:45       Roma  Sampdoria      3 : 1
# 4  Giornata 38               22.05. 20:45    Udinese      Milan      0 : 0

# %%
gg.df.columns = ["day", "date", "home", "visitor", "result"]

# %%
gg.df.head()
# Out:
#            day          date      home    visitor result
# 0  Giornata 38           NaN       NaN        NaN    NaN
# 1  Giornata 38  22.05. 20:45  Juventus     Napoli  2 : 2
# 2  Giornata 38  22.05. 20:45     Lecce      Lazio  2 : 4
# 3  Giornata 38  22.05. 20:45      Roma  Sampdoria  3 : 1
# 4  Giornata 38  22.05. 20:45   Udinese      Milan  0 : 0

# %%
gg.df["day"].fillna(method='ffill', inplace=True)

# %%
gg.df.dropna(inplace=True)

# %%
gg.df.head()
# Out:
#            day          date      home    visitor result
# 1  Giornata 38  22.05. 20:45  Juventus     Napoli  2 : 2
# 2  Giornata 38  22.05. 20:45     Lecce      Lazio  2 : 4
# 3  Giornata 38  22.05. 20:45      Roma  Sampdoria  3 : 1
# 4  Giornata 38  22.05. 20:45   Udinese      Milan  0 : 0
# 5  Giornata 38  22.05. 18:00   Bologna       Bari  0 : 4

# %%
type(gg.df["result"][0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-0ed66d7fcd21> in <module>()
# ----> 1 type(gg.df["result"][0])
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     621         key = com._apply_if_callable(key, self)
#     622         try:
# --> 623             result = self.index.get_value(self, key)
#     624
#     625             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    2558         try:
#    2559             return self._engine.get_value(s, k,
# -> 2560                                           tz=getattr(series.dtype, 'tz', None))
#    2561         except KeyError as e1:
#    2562             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0

# %%
gg.df["result"][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-2bee87508ea8> in <module>()
# ----> 1 gg.df["result"][0]
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     621         key = com._apply_if_callable(key, self)
#     622         try:
# --> 623             result = self.index.get_value(self, key)
#     624
#     625             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    2558         try:
#    2559             return self._engine.get_value(s, k,
# -> 2560                                           tz=getattr(series.dtype, 'tz', None))
#    2561         except KeyError as e1:
#    2562             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0

# %%
def pools(result):
    # func to find the outcome 1,X,2 in the game sheet
    goals_home = int(result.split(":")[0])
    goals_visitor = int(result.split(":")[1])
    
    if goals_home > goals_visitor:
        return 1
    elif goals_home < goals_visitor:
        return 2
    else:
        return "X"

# %%
gg.df['pools'] = gg.df["result"].apply(lambda x: pools(x))

# %%
gg.df.head()
# Out:
#            day          date      home    visitor result pools
# 1  Giornata 38  22.05. 20:45  Juventus     Napoli  2 : 2     X
# 2  Giornata 38  22.05. 20:45     Lecce      Lazio  2 : 4     2
# 3  Giornata 38  22.05. 20:45      Roma  Sampdoria  3 : 1     1
# 4  Giornata 38  22.05. 20:45   Udinese      Milan  0 : 0     X
# 5  Giornata 38  22.05. 18:00   Bologna       Bari  0 : 4     2
